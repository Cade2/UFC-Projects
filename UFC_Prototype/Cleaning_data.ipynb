# %%
import datetime
print(f"Last updated: {datetime.datetime.now()}")
# Out:
# Last updated: 2025-01-24 14:06:33.125282

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **# 1. Get the data ready**

# %%
event = pd.read_csv("data/ufc_event_details.csv")
event
# Out:
#                                       EVENT  \
# 0            UFC 311: Makhachev vs. Moicano
# 1         UFC Fight Night: Dern vs. Ribas 2
# 2    UFC Fight Night: Covington vs. Buckley
# 3              UFC 310: Pantoja vs. Asakura
# 4       UFC Fight Night: Yan vs. Figueiredo
# ..                                      ...
# 712              UFC 6: Clash of the Titans
# 713          UFC 5: The Return of the Beast
# 714          UFC 4: Revenge of the Warriors
# 715               UFC 3: The American Dream
# 716                       UFC 2: No Way Out
#
#                                                    URL                DATE  \
# 0    http://ufcstats.com/event-details/39f68882def7...    January 18, 2025
# 1    http://ufcstats.com/event-details/81ddc98fceb3...    January 11, 2025
# 2    http://ufcstats.com/event-details/72c9c2eadfc3...   December 14, 2024
# 3    http://ufcstats.com/event-details/ad23903ef3af...   December 07, 2024
# ...

# %%
fight_details = pd.read_csv("data/ufc_fight_details.csv")
fight_details
# Out:
#                                EVENT                                     BOUT  \
# 0     UFC 311: Makhachev vs. Moicano       Islam Makhachev vs. Renato Moicano
# 1     UFC 311: Makhachev vs. Moicano  Merab Dvalishvili vs. Umar Nurmagomedov
# 2     UFC 311: Makhachev vs. Moicano          Jiri Prochazka vs. Jamahal Hill
# 3     UFC 311: Makhachev vs. Moicano       Jailton Almeida vs. Serghei Spivac
# 4     UFC 311: Makhachev vs. Moicano      Reinier de Ridder vs. Kevin Holland
# ...                              ...                                      ...
# 7970               UFC 2: No Way Out        Orlando Wiet vs. Robert Lucarelli
# 7971               UFC 2: No Way Out        Frank Hamaker vs. Thaddeus Luster
# 7972               UFC 2: No Way Out          Johnny Rhodes vs. David Levicki
# 7973               UFC 2: No Way Out             Patrick Smith vs. Ray Wizard
# 7974               UFC 2: No Way Out          Scott Morris vs. Sean Daugherty
#
# ...

# %%
fight_results = pd.read_csv("data/ufc_fight_results.csv")
fight_results
# Out:
#                                 EVENT  \
# 0     UFC 311: Makhachev vs. Moicano
# 1     UFC 311: Makhachev vs. Moicano
# 2     UFC 311: Makhachev vs. Moicano
# 3     UFC 311: Makhachev vs. Moicano
# 4     UFC 311: Makhachev vs. Moicano
# ...                               ...
# 7957               UFC 2: No Way Out
# 7958               UFC 2: No Way Out
# 7959               UFC 2: No Way Out
# 7960               UFC 2: No Way Out
# 7961               UFC 2: No Way Out
#
#                                            BOUT OUTCOME  \
# 0          Islam Makhachev  vs. Renato Moicano      W/L
# 1     Merab Dvalishvili  vs. Umar Nurmagomedov      W/L
# 2             Jiri Prochazka  vs. Jamahal Hill      W/L
# 3          Jailton Almeida  vs. Serghei Spivac      W/L
# 4         Kevin Holland  vs. Reinier de Ridder      L/W
# ...                                         ...     ...
# 7957        Orlando Wiet  vs. Robert Lucarelli      W/L
# 7958        Frank Hamaker  vs. Thaddeus Luster      W/L
# ...

# %%
fight_stats = pd.read_csv("data/ufc_fight_stats.csv")
fight_stats
# Out:
#                                 EVENT  \
# 0      UFC 311: Makhachev vs. Moicano
# 1      UFC 311: Makhachev vs. Moicano
# 2      UFC 311: Makhachev vs. Moicano
# 3      UFC 311: Makhachev vs. Moicano
# 4      UFC 311: Makhachev vs. Moicano
# ...                               ...
# 37423               UFC 2: No Way Out
# 37424               UFC 2: No Way Out
# 37425               UFC 2: No Way Out
# 37426               UFC 2: No Way Out
# 37427               UFC 2: No Way Out
#
#                                           BOUT    ROUND            FIGHTER  \
# 0           Islam Makhachev vs. Renato Moicano  Round 1    Islam Makhachev
# 1           Islam Makhachev vs. Renato Moicano  Round 1     Renato Moicano
# 2      Merab Dvalishvili vs. Umar Nurmagomedov  Round 1  Merab Dvalishvili
# 3      Merab Dvalishvili vs. Umar Nurmagomedov  Round 2  Merab Dvalishvili
# 4      Merab Dvalishvili vs. Umar Nurmagomedov  Round 3  Merab Dvalishvili
# ...

# %%
fighter_details = pd.read_csv("data/ufc_fighter_details.csv")
fighter_details
# Out:
#         FIRST        LAST      NICKNAME  \
# 0         Tom       Aaron           NaN
# 1       Danny      Abbadi  The Assassin
# 2     Nariman     Abbasov     Bayraktar
# 3       David      Abbott          Tank
# 4       Hamdy  Abdelwahab    The Hammer
# ...       ...         ...           ...
# 4262     Dave    Zitanick           NaN
# 4263     Alex      Zuniga           NaN
# 4264   George      Zuniga           NaN
# 4265    Allan      Zuniga         Tigre
# 4266   Virgil     Zwicker        RezDog
#
#                                                     URL
# 0     http://ufcstats.com/fighter-details/93fe7332d1...
# 1     http://ufcstats.com/fighter-details/15df64c02b...
# 2     http://ufcstats.com/fighter-details/59a9d6dac6...
# 3     http://ufcstats.com/fighter-details/b361180739...
# 4     http://ufcstats.com/fighter-details/3329d692ae...
# ...                                                 ...
# 4262  http://ufcstats.com/fighter-details/be124bdd60...
# ...

# %%
fighter_tott = pd.read_csv("data/ufc_fighter_tott.csv")
fighter_tott
# Out:
#                   FIGHTER  HEIGHT    WEIGHT REACH    STANCE           DOB  \
# 0               Tom Aaron      --  155 lbs.    --       NaN  Jul 13, 1978
# 1            Danny Abbadi  5' 11"  155 lbs.    --  Orthodox  Jul 03, 1983
# 2            David Abbott   6' 0"  265 lbs.    --    Switch            --
# 3     Shamil Abdurakhimov   6' 3"  235 lbs.   76"  Orthodox  Sep 02, 1981
# 4            Hiroyuki Abe   5' 6"  145 lbs.    --  Orthodox            --
# ...                   ...     ...       ...   ...       ...           ...
# 4267      Kennedy Freeman      --  135 lbs.    --       NaN  Nov 26, 1996
# 4268        Alice Pereira      --  135 lbs.    --       NaN  Dec 20, 2005
# 4269        Billy Elekana      --  205 lbs.    --  Southpaw  May 28, 1995
# 4270        Azamat Bekoev      --  185 lbs.    --       NaN  Dec 30, 1995
# 4271       Matheus Camilo      --  155 lbs.    --       NaN  Jan 02, 2001
#
#                                                     URL
# ...

# %%
event.isna().sum()
# Out:
# EVENT       0
# URL         0
# DATE        0
# LOCATION    0
# dtype: int64

# %%
fight_details.isna().sum()
# Out:
# EVENT    0
# BOUT     0
# URL      0
# dtype: int64

# %%
fight_results.isna().sum()
# Out:
# EVENT           0
# BOUT            0
# OUTCOME         0
# WEIGHTCLASS     0
# METHOD          0
# ROUND           0
# TIME            0
# TIME FORMAT     0
# REFEREE        34
# DETAILS        77
# URL             0
# dtype: int64

# %%
fight_stats.isna().sum()
# Out:
# EVENT          0
# BOUT           0
# ROUND         42
# FIGHTER       42
# KD            42
# SIG.STR.      42
# SIG.STR. %    42
# TOTAL STR.    42
# TD            42
# TD %          42
# SUB.ATT       42
# REV.          42
# CTRL          42
# HEAD          42
# BODY          42
# LEG           42
# DISTANCE      42
# CLINCH        42
# GROUND        42
# dtype: int64

# %%
fighter_details.isna().sum()
# Out:
# FIRST       13
# LAST         0
# NICKNAME     0
# URL          0
# dtype: int64

# %%
fighter_tott.isna().sum()
# Out:
# FIGHTER       0
# HEIGHT        0
# WEIGHT        0
# REACH         0
# STANCE     1328
# DOB           0
# URL           0
# dtype: int64

# %%
missing_rows = fight_results[fight_results.isnull().any(axis=1)]

# Display the rows with missing values
print(missing_rows)
missing_rows.to_csv('missing_rows_fight_details.csv', index=False)
# Out:
#                                           EVENT  \
# 75                   UFC 309: Jones vs. Miocic
# 115          UFC Fight Night: Royval vs. Taira
# 138   UFC Fight Night: Moicano vs. Saint Denis
# 258           UFC 303: Pereira vs. Prochazka 2
# 793     UFC Fight Night: Vettori vs. Cannonier
# ...                                         ...
# 7891               UFC - Ultimate Ultimate '95
# 7892               UFC - Ultimate Ultimate '95
# 7893               UFC - Ultimate Ultimate '95
# 7898               UFC - Ultimate Ultimate '95
# 7910               UFC 7: The Brawl in Buffalo
#
#                                          BOUT OUTCOME  \
# 75          Marcin Tybura  vs. Jhonata Diniz      W/L
# 115           Brad Tavares  vs. JunYong Park      L/W
# 138   Renato Moicano  vs. Benoit Saint Denis      W/L
# 258                 Dan Ige  vs. Diego Lopes      L/W
# 793         Dan Argueta  vs. Ronnie Lawrence    NC/NC
# ...                                       ...     ...
# ...

# %%
missing_row_fight_details = pd.read_csv("missing_rows_fight_details.csv")
missing_row_fight_details
# Out:
#                                          EVENT  \
# 0                   UFC 309: Jones vs. Miocic
# 1           UFC Fight Night: Royval vs. Taira
# 2    UFC Fight Night: Moicano vs. Saint Denis
# 3            UFC 303: Pereira vs. Prochazka 2
# 4      UFC Fight Night: Vettori vs. Cannonier
# ..                                         ...
# 105               UFC - Ultimate Ultimate '95
# 106               UFC - Ultimate Ultimate '95
# 107               UFC - Ultimate Ultimate '95
# 108               UFC - Ultimate Ultimate '95
# 109               UFC 7: The Brawl in Buffalo
#
#                                         BOUT OUTCOME  \
# 0          Marcin Tybura  vs. Jhonata Diniz      W/L
# 1            Brad Tavares  vs. JunYong Park      L/W
# 2    Renato Moicano  vs. Benoit Saint Denis      W/L
# 3                  Dan Ige  vs. Diego Lopes      L/W
# 4          Dan Argueta  vs. Ronnie Lawrence    NC/NC
# ..                                       ...     ...
# ...

# %%
# Replace NaN in DETAILS where METHOD is "TKO - Doctor's Stoppage"
fight_results.loc[
    (fight_results["METHOD"] == "TKO - Doctor's Stoppage") & (fight_results["DETAILS"].isnull()),
    "DETAILS"
] = "Doctor's Stoppage"

# Verify if NaN values were reduced
print(fight_results.isna().sum())
# Out:
# EVENT           0
# BOUT            0
# OUTCOME         0
# WEIGHTCLASS     0
# METHOD          0
# ROUND           0
# TIME            0
# TIME FORMAT     0
# REFEREE        34
# DETAILS        77
# URL             0
# dtype: int64

# %%
# Ensure no leading/trailing whitespace in columns
fight_results["METHOD"] = fight_results["METHOD"].str.strip()

# Replace NaN values in DETAILS where METHOD is "TKO - Doctor's Stoppage"
fight_results.loc[
    (fight_results["METHOD"] == "TKO - Doctor's Stoppage") & (fight_results["DETAILS"].isnull()),
    "DETAILS"
] = "Doctor's Stoppage"

# Verify if NaN values were reduced
fight_results.isna().sum()
# Out:
# EVENT           0
# BOUT            0
# OUTCOME         0
# WEIGHTCLASS     0
# METHOD          0
# ROUND           0
# TIME            0
# TIME FORMAT     0
# REFEREE        34
# DETAILS        60
# URL             0
# dtype: int64

# %%
fight_results
# Out:
#                                 EVENT  \
# 0     UFC 311: Makhachev vs. Moicano
# 1     UFC 311: Makhachev vs. Moicano
# 2     UFC 311: Makhachev vs. Moicano
# 3     UFC 311: Makhachev vs. Moicano
# 4     UFC 311: Makhachev vs. Moicano
# ...                               ...
# 7957               UFC 2: No Way Out
# 7958               UFC 2: No Way Out
# 7959               UFC 2: No Way Out
# 7960               UFC 2: No Way Out
# 7961               UFC 2: No Way Out
#
#                                            BOUT OUTCOME  \
# 0          Islam Makhachev  vs. Renato Moicano      W/L
# 1     Merab Dvalishvili  vs. Umar Nurmagomedov      W/L
# 2             Jiri Prochazka  vs. Jamahal Hill      W/L
# 3          Jailton Almeida  vs. Serghei Spivac      W/L
# 4         Kevin Holland  vs. Reinier de Ridder      L/W
# ...                                         ...     ...
# 7957        Orlando Wiet  vs. Robert Lucarelli      W/L
# 7958        Frank Hamaker  vs. Thaddeus Luster      W/L
# ...

# %%
missing_rows = fight_results[fight_results.isnull().any(axis=1)]

# Display the rows with missing values
print(missing_rows)
#missing_rows.to_csv('missing_rows.csv', index=False)
# Out:
#                                          EVENT  \
# 115         UFC Fight Night: Royval vs. Taira
# 258          UFC 303: Pereira vs. Prochazka 2
# 793    UFC Fight Night: Vettori vs. Cannonier
# 1943    UFC Fight Night: Edwards vs. Muhammad
# 2069  UFC Fight Night: Hermansson vs. Vettori
# ...                                        ...
# 7888                  UFC 8: David vs Goliath
# 7891              UFC - Ultimate Ultimate '95
# 7892              UFC - Ultimate Ultimate '95
# 7893              UFC - Ultimate Ultimate '95
# 7898              UFC - Ultimate Ultimate '95
#
#                                      BOUT OUTCOME  \
# 115       Brad Tavares  vs. JunYong Park      L/W
# 258             Dan Ige  vs. Diego Lopes      L/W
# 793     Dan Argueta  vs. Ronnie Lawrence    NC/NC
# 1943     Manel Kape  vs. Matheus Nicolau      L/W
# 2069  Gabriel Benitez  vs. Justin Jaynes      W/L
# ...                                   ...     ...
# ...

# %%
missing_row_fight_details
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 missing_row_fight_details
#
# NameError: name 'missing_row_fight_details' is not defined

# %%
# Ensure no leading/trailing whitespace in columns
fight_results["METHOD"] = fight_results["METHOD"].str.strip()

# Replace NaN values in DETAILS where METHOD is "TKO - Doctor's Stoppage"
fight_results.loc[
    (fight_results["METHOD"] == "Overturned") & (fight_results["DETAILS"].isnull()),
    "DETAILS"
] = "No Contest"

# Verify if NaN values were reduced
fight_results.isna().sum()
# Out:
# EVENT           0
# BOUT            0
# OUTCOME         0
# WEIGHTCLASS     0
# METHOD          0
# ROUND           0
# TIME            0
# TIME FORMAT     0
# REFEREE        34
# DETAILS        58
# URL             0
# dtype: int64

# %%
missing_rows = fight_results[fight_results.isnull().any(axis=1)]

# Display the rows with missing values
missing_rows
#missing_rows.to_csv('missing_rows.csv', index=False)
# Out:
# Empty DataFrame
# Columns: [EVENT, BOUT, OUTCOME, WEIGHTCLASS, METHOD, ROUND, TIME, TIME FORMAT, REFEREE, DETAILS, URL]
# Index: []

# %%
fight_results.at[115,'REFEREE'] = 'Herb Dean'
fight_results.isna().sum()
# Out:
# EVENT          0
# BOUT           0
# OUTCOME        0
# WEIGHTCLASS    0
# METHOD         0
# ROUND          0
# TIME           0
# TIME FORMAT    0
# REFEREE        0
# DETAILS        0
# URL            0
# dtype: int64

# %%
#fight_results.at[7898,'DETAILS'] = 'Armlock'

# %%
# Ensure no leading/trailing whitespace in columns
fight_results["METHOD"] = fight_results["METHOD"].str.strip()

# Replace NaN values in DETAILS where METHOD is "TKO - Doctor's Stoppage"
fight_results.loc[
    (fight_results["METHOD"] == "Decision - Split") & (fight_results["DETAILS"].isnull()),
    "DETAILS"
] = "Split Decision"

# Verify if NaN values were reduced
fight_results.isna().sum()
# Out:
# EVENT           0
# BOUT            0
# OUTCOME         0
# WEIGHTCLASS     0
# METHOD          0
# ROUND           0
# TIME            0
# TIME FORMAT     0
# REFEREE        33
# DETAILS        49
# URL             0
# dtype: int64

# %%
# Ensure no leading/trailing whitespace in columns
fight_results["METHOD"] = fight_results["METHOD"].str.strip()

# Replace NaN values in DETAILS where METHOD is "TKO - Doctor's Stoppage"
fight_results.loc[
    (fight_results["METHOD"] == "Decision - Majority") & (fight_results["DETAILS"].isnull()),
    "DETAILS"
] = "Majority Decision"

# Verify if NaN values were reduced
fight_results.isna().sum()
# Out:
# EVENT           0
# BOUT            0
# OUTCOME         0
# WEIGHTCLASS     0
# METHOD          0
# ROUND           0
# TIME            0
# TIME FORMAT     0
# REFEREE        33
# DETAILS        45
# URL             0
# dtype: int64

# %%
# Ensure no leading/trailing whitespace in columns
fight_results["METHOD"] = fight_results["METHOD"].str.strip()

# Replace NaN values in DETAILS where METHOD is "TKO - Doctor's Stoppage"
fight_results.loc[
    (fight_results["METHOD"] == "Decision - Unanimous") & (fight_results["DETAILS"].isnull()),
    "DETAILS"
] = "Unanimous Decision"

# Verify if NaN values were reduced
fight_results.isna().sum()
# Out:
# EVENT           0
# BOUT            0
# OUTCOME         0
# WEIGHTCLASS     0
# METHOD          0
# ROUND           0
# TIME            0
# TIME FORMAT     0
# REFEREE        33
# DETAILS         1
# URL             0
# dtype: int64

# %%
fight_results.to_csv('ufc_fight_results', index=False)

# %%
fight_results.to_csv('fight_results.csv', index=False)

# %%
fight_results = pd.read_csv("fight_results.csv")
fight_results
# Out:
#                                 EVENT  \
# 0     UFC 311: Makhachev vs. Moicano
# 1     UFC 311: Makhachev vs. Moicano
# 2     UFC 311: Makhachev vs. Moicano
# 3     UFC 311: Makhachev vs. Moicano
# 4     UFC 311: Makhachev vs. Moicano
# ...                               ...
# 7957               UFC 2: No Way Out
# 7958               UFC 2: No Way Out
# 7959               UFC 2: No Way Out
# 7960               UFC 2: No Way Out
# 7961               UFC 2: No Way Out
#
#                                            BOUT OUTCOME  \
# 0          Islam Makhachev  vs. Renato Moicano      W/L
# 1     Merab Dvalishvili  vs. Umar Nurmagomedov      W/L
# 2             Jiri Prochazka  vs. Jamahal Hill      W/L
# 3          Jailton Almeida  vs. Serghei Spivac      W/L
# 4         Kevin Holland  vs. Reinier de Ridder      L/W
# ...                                         ...     ...
# 7957        Orlando Wiet  vs. Robert Lucarelli      W/L
# 7958        Frank Hamaker  vs. Thaddeus Luster      W/L
# ...

# %%
fight_results.isna().sum()
# Out:
# EVENT           0
# BOUT            0
# OUTCOME         0
# WEIGHTCLASS     0
# METHOD          0
# ROUND           0
# TIME            0
# TIME FORMAT     0
# REFEREE        33
# DETAILS         1
# URL             0
# dtype: int64

# %%
fight_stats.isna().sum()
# Out:
# EVENT          0
# BOUT           0
# ROUND         42
# FIGHTER       42
# KD            42
# SIG.STR.      42
# SIG.STR. %    42
# TOTAL STR.    42
# TD            42
# TD %          42
# SUB.ATT       42
# REV.          42
# CTRL          42
# HEAD          42
# BODY          42
# LEG           42
# DISTANCE      42
# CLINCH        42
# GROUND        42
# dtype: int64

# %%
missing_rows = fight_stats[fight_stats.isnull().any(axis=1)]

# Display the rows with missing values
missing_rows
#missing_rows.to_csv('missing_rows.csv', index=False)
# Out:
#                                 EVENT                                   BOUT  \
# 37040           UFC - Ultimate Brazil       Cesar Marscucci vs. Paulo Santos
# 37041           UFC - Ultimate Brazil       Cesar Marscucci vs. Paulo Santos
# 37064              UFC 17: Redemption      Andre Roberts vs. Harry Moskowitz
# 37065              UFC 17: Redemption      Andre Roberts vs. Harry Moskowitz
# 37084     UFC 16: Battle in the Bayou      Chris Brennan vs. Courtney Turner
# 37085     UFC 16: Battle in the Bayou      Chris Brennan vs. Courtney Turner
# 37086     UFC 16: Battle in the Bayou          Laverne Clark vs. Josh Stuart
# 37087     UFC 16: Battle in the Bayou          Laverne Clark vs. Josh Stuart
# 37184           UFC 12: Judgement Day          Justin Martin vs. Eric Martin
# 37185           UFC 12: Judgement Day          Justin Martin vs. Eric Martin
# 37186           UFC 12: Judgement Day              Nick Sanzo vs. Jackie Lee
# ...

# %%
fight_stats.dropna(inplace=True)
fight_stats.isna().sum()
# Out:
# EVENT         0
# BOUT          0
# ROUND         0
# FIGHTER       0
# KD            0
# SIG.STR.      0
# SIG.STR. %    0
# TOTAL STR.    0
# TD            0
# TD %          0
# SUB.ATT       0
# REV.          0
# CTRL          0
# HEAD          0
# BODY          0
# LEG           0
# DISTANCE      0
# CLINCH        0
# GROUND        0
# dtype: int64

# %%
fighter_details.isna().sum()
# Out:
# FIRST         14
# LAST           0
# NICKNAME    1913
# URL            0
# dtype: int64

# %%
missing_rows = fighter_details[fighter_details.isnull().any(axis=1)]
missing_rows
# Out:
#         FIRST         LAST NICKNAME  \
# 0         Tom        Aaron      NaN
# 5      Mansur  Abdul-Malik      NaN
# 8      Daichi          Abe      NaN
# 12     Cyborg        Abreu      NaN
# 13     Daniel       Acacio      NaN
# ...       ...          ...      ...
# 4255  Zhalgas   Zhumagulov      NaN
# 4257     Mike     Zichelle      NaN
# 4262     Dave     Zitanick      NaN
# 4263     Alex       Zuniga      NaN
# 4264   George       Zuniga      NaN
#
#                                                     URL
# 0     http://ufcstats.com/fighter-details/93fe7332d1...
# 5     http://ufcstats.com/fighter-details/841695e02c...
# 8     http://ufcstats.com/fighter-details/5140122c3e...
# 12    http://ufcstats.com/fighter-details/f689bd7bbd...
# 13    http://ufcstats.com/fighter-details/1c5879330d...
# ...                                                 ...
# 4255  http://ufcstats.com/fighter-details/55fa6ce3e5...
# 4257  http://ufcstats.com/fighter-details/6d3398b910...
# ...

# %%
fighter_details.at[4208,'FIRST'] = 'Yizha'
fighter_details.at[4208,'LAST'] = ''
fighter_details.isna().sum()
# Out:
# FIRST         13
# LAST           0
# NICKNAME    1913
# URL            0
# dtype: int64

# %%
fighter_details["NICKNAME"].fillna("", inplace=True)
fighter_details.isna().sum()
# Out:
# C:\Users\cadeb\AppData\Local\Temp\ipykernel_13644\2569229660.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fighter_details["NICKNAME"].fillna("", inplace=True)
# FIRST       13
# LAST         0
# NICKNAME     0
# URL          0
# dtype: int64

# %%
fighter_tott.isna().sum()
# Out:
# FIGHTER       0
# HEIGHT        0
# WEIGHT        0
# REACH         0
# STANCE     1328
# DOB           0
# URL           0
# dtype: int64

# %%
missing_rows = fighter_tott[fighter_tott.isnull().any(axis=1)]
missing_rows
# Out:
#               FIGHTER  HEIGHT    WEIGHT REACH STANCE           DOB  \
# 0           Tom Aaron      --  155 lbs.    --    NaN  Jul 13, 1978
# 19       Fabio Aguiar   6' 0"  185 lbs.    --    NaN  Feb 10, 1988
# 20      Edwin Aguilar  5' 10"  185 lbs.    --    NaN            --
# 32        Javi Alanis   5' 6"  135 lbs.    --    NaN            --
# 35        Brett Albee      --  225 lbs.    --    NaN            --
# ...               ...     ...       ...   ...    ...           ...
# 4266   Roberto Romero      --  155 lbs.    --    NaN  Jan 30, 2000
# 4267  Kennedy Freeman      --  135 lbs.    --    NaN  Nov 26, 1996
# 4268    Alice Pereira      --  135 lbs.    --    NaN  Dec 20, 2005
# 4270    Azamat Bekoev      --  185 lbs.    --    NaN  Dec 30, 1995
# 4271   Matheus Camilo      --  155 lbs.    --    NaN  Jan 02, 2001
#
#                                                     URL
# 0     http://ufcstats.com/fighter-details/93fe7332d1...
# ...

# %%
stance_nan_values = fighter_tott['STANCE'].isna()

# Calculate the number of missing values for each stance based on the given percentages
total_nan = stance_nan_values.sum()
orthodox_count = int(total_nan * 0.76)
southpaw_count = int(total_nan * 0.21)
switch_count = total_nan - orthodox_count - southpaw_count

# Create an array with the respective counts for each stance
stance_fill_values = (
    ["Orthodox"] * orthodox_count +
    ["Southpaw"] * southpaw_count +
    ["Switch"] * switch_count
)

# Shuffle the array to randomize the assignment
np.random.shuffle(stance_fill_values)

# Fill the missing values in the 'STANCE' column with the generated values
fighter_tott.loc[stance_nan_values, 'STANCE'] = stance_fill_values


fighter_tott.isna().sum()
# Out:
# FIGHTER    0
# HEIGHT     0
# WEIGHT     0
# REACH      0
# STANCE     0
# DOB        0
# URL        0
# dtype: int64

# %%
event.isna().sum()
# Out:
# EVENT       0
# URL         0
# DATE        0
# LOCATION    0
# dtype: int64

# %%
fight_details.isna().sum()
# Out:
# EVENT    0
# BOUT     0
# URL      0
# dtype: int64

# %%
fight_results.isna().sum()
# Out:
# EVENT          0
# BOUT           0
# OUTCOME        0
# WEIGHTCLASS    0
# METHOD         0
# ROUND          0
# TIME           0
# TIME FORMAT    0
# REFEREE        0
# DETAILS        0
# URL            0
# dtype: int64

# %%
fight_stats.isna().sum()
# Out:
# EVENT         0
# BOUT          0
# ROUND         0
# FIGHTER       0
# KD            0
# SIG.STR.      0
# SIG.STR. %    0
# TOTAL STR.    0
# TD            0
# TD %          0
# SUB.ATT       0
# REV.          0
# CTRL          0
# HEAD          0
# BODY          0
# LEG           0
# DISTANCE      0
# CLINCH        0
# GROUND        0
# dtype: int64

# %%
fighter_details.isna().sum()
# Out:
# FIRST       13
# LAST         0
# NICKNAME     0
# URL          0
# dtype: int64

# %%
fighter_tott.isna().sum()
# Out:
# FIGHTER    0
# HEIGHT     0
# WEIGHT     0
# REACH      0
# STANCE     0
# DOB        0
# URL        0
# dtype: int64

# %%
fighter_tott.replace(["--", "---"], pd.NA, inplace=True)
fighter_tott.isna().sum()
# Out:
# FIGHTER       0
# HEIGHT      719
# WEIGHT      100
# REACH      2432
# STANCE        0
# DOB         862
# URL           0
# dtype: int64

# %%
missing_rows.dtypes
# Out:
# FIGHTER    object
# HEIGHT     object
# WEIGHT     object
# REACH      object
# STANCE     object
# DOB        object
# URL        object
# dtype: object

# %%
missing_rows = fighter_tott[fighter_tott.isnull().any(axis=1)]
missing_rows
# Out:
#               FIGHTER  HEIGHT    WEIGHT REACH    STANCE           DOB  \
# 0           Tom Aaron    <NA>  155 lbs.  <NA>  Southpaw  Jul 13, 1978
# 1        Danny Abbadi  5' 11"  155 lbs.  <NA>  Orthodox  Jul 03, 1983
# 2        David Abbott   6' 0"  265 lbs.  <NA>    Switch          <NA>
# 4        Hiroyuki Abe   5' 6"  145 lbs.  <NA>  Orthodox          <NA>
# 6          Papy Abedi  5' 11"  185 lbs.  <NA>  Southpaw  Jun 30, 1978
# ...               ...     ...       ...   ...       ...           ...
# 4267  Kennedy Freeman    <NA>  135 lbs.  <NA>  Southpaw  Nov 26, 1996
# 4268    Alice Pereira    <NA>  135 lbs.  <NA>  Orthodox  Dec 20, 2005
# 4269    Billy Elekana    <NA>  205 lbs.  <NA>  Southpaw  May 28, 1995
# 4270    Azamat Bekoev    <NA>  185 lbs.  <NA>  Orthodox  Dec 30, 1995
# 4271   Matheus Camilo    <NA>  155 lbs.  <NA>  Orthodox  Jan 02, 2001
#
#                                                     URL
# 0     http://ufcstats.com/fighter-details/93fe7332d1...
# ...

# %%
fighter_tott.at[0,'HEIGHT'] = '5' 8"'
fighter_tott.at[0,'REACH'] = ''
#fighter_tott.at[0,'DOB'] = ''
fighter_tott.isna().sum()

# %%
# Extract unique fighter names with any NaN values in their row
fighters_with_nan = fighter_tott[fighter_tott.isna().any(axis=1)]['FIGHTER'].unique()

fighters_with_nan.tolist()
# Out:
# ['Tom Aaron',
#  'Danny Abbadi',
#  'David Abbott',
#  'Hiroyuki Abe',
#  'Papy Abedi',
#  'Ricardo Abreu',
#  'Daniel Acacio',
#  'Scott Adams',
#  'Sam Adkins',
#  'Nick Agallar',
#  'Marcelo Aguiar',
#  'Fabio Aguiar',
#  'Edwin Aguilar',
#  'Mike Aina',
#  'Hitomi Akano',
#  'Razak Al-Hassan',
#  'Javi Alanis',
#  'Brett Albee',
#  'Wes Albritton',
#  'Israel Albuquerque',
#  'Juan Alcain',
#  'Alfonso Alcarez',
#  'Gilbert Aldana',
#  'Kenneth Alexander',
#  'Olaf Alfonso',
#  'Pablo Alfonso',
#  'Levi Alford',
#  'Royce Alger',
#  'Amir Aliakbari',
#  'George Allen',
#  'Magno Almeida',
#  'Ericka Almeida',
#  'Estefani Almeida',
#  'Mauricio Alonso',
#  'Rico Altamirano',
#  'Mike Altman',
#  'Sean Alvarez',
#  'Anthony Alves',
#  'Amilcar Alves',
#  'Andre Amado',
#  'Maiara Amanajas dos Santos',
#  'Chris Amarante',
#  'Jimmy Ambriz',
#  'JJ Ambrose',
#  'Bertrand Amoussou',
#  'Karl Amoussou',
#  'Matt Andersen',
#  'Andy Anderson',
#  'Lowell Anderson',
# ...

# %%
# Redefine the list of files to search
files_to_search = {
    "Cleaner_Fight_Results": "data/Cleaner_Fight_Results.csv",
    "Fight_Details": "data/fight_details.csv",
    "Fight_Event": "data/fight_event.csv",
    "Fighter_Details": "data/fighter_details.csv",
    "Fight_Stats_Percentages": "data/fight_stats_percentages_updated.csv",
}

# Reload the full list of names with NaN values
full_names_with_nan = ['Tom Aaron',
 'Danny Abbadi',
 'David Abbott',
 'Hiroyuki Abe',
 'Papy Abedi',
 'Ricardo Abreu',
 'Daniel Acacio',
 'Scott Adams',
 'Sam Adkins',
 'Nick Agallar',
 'Marcelo Aguiar',
 'Fabio Aguiar',
 'Edwin Aguilar',
 'Mike Aina',
 'Hitomi Akano',
 'Razak Al-Hassan',
 'Javi Alanis',
 'Brett Albee',
 'Wes Albritton',
 'Israel Albuquerque',
 'Juan Alcain',
 'Alfonso Alcarez',
 'Gilbert Aldana',
 'Kenneth Alexander',
 'Olaf Alfonso',
 'Pablo Alfonso',
 'Levi Alford',
 'Royce Alger',
 'Amir Aliakbari',
 'George Allen',
 'Magno Almeida',
 'Ericka Almeida',
 'Estefani Almeida',
 'Mauricio Alonso',
 'Rico Altamirano',
 'Mike Altman',
 'Sean Alvarez',
 'Anthony Alves',
 'Amilcar Alves',
 'Andre Amado',
 'Maiara Amanajas dos Santos',
 'Chris Amarante',
 'Jimmy Ambriz',
 'JJ Ambrose',
 'Bertrand Amoussou',
 'Karl Amoussou',
 'Matt Andersen',
 'Andy Anderson',
 'Lowell Anderson',
 'Derek Anderson',
 'Alex Andrade',
 'Jermaine Andre',
 'Reese Andy',
 'Julius Anglickas',
 'Yoji Anjo',
 'Angelo Antonio',
 'Azunna Anyanwu',
 'Shinya Aoki',
 'Josh Appelt',
 'Erik Apple',
 'Kenji Arai',
 'Romie Aram',
 'Art Arciniega',
 'Tristan Arenal',
 'Joey Armstrong',
 'Ricardo Arona',
 'Chalid Arrab',
 'Gilles Arsene',
 'Veta Arteaga',
 'Cesar Arzamendia',
 'Arman Ashimov',
 'Khusein Askhabov',
 'Ibo Aslan',
 'Bruno Assis',
 'Bazigit Atajev',
 'Pat Audinwood',
 'Jose Augusto',
 'David Avellan',
 'Levi Avera',
 'Anthony Avila',
 'Chris Avila',
 'Saad Awad',
 'Javy Ayala',
 'Luiz Azeredo',
 'Luciano Azevedo',
 'Niklas Backstrom',
 'Izabela Badurek',
 'Mehdi Baghdad',
 'Jordan Bailey',
 'Scott Baker',
 'Bryan Baker',
 'Jin Bala',
 'Stephen Banaszak',
 'Marcin Bandel',
 'Yohan Banks',
 'Junior Barata',
 'Nick Barnes',
 'Chris Barnhizer',
 'David Baron',
 'Dan Barrera',
 'Carlos Barreto',
 'Jose Barreto',
 'David Barrios',
 'Alexandre Barros',
 'Ricardo Barros',
 'Dean Barry',
 'Stephen Bass',
 'Sean Bassett',
 'Ryan Bastianelli',
 'Shayna Baszler',
 'Michel Batista',
 'Rudy Bears',
 'Salvador Becerra',
 'Jeff Bedard',
 'Eric Bedard',
 'Lyle Beerbohm',
 'Mike Bencic',
 'Dave Beneteau',
 'Karla Benitez',
 'Charles Bennett',
 'Josh Bennett',
 'Joe Benoit',
 'Pat Benson',
 'Len Bentley',
 'Steve Berger',
 'Bret Bergmark',
 'Keith Berish',
 'Dave Berry',
 'Keith Berry',
 'Dieusel Berto',
 'Edson Berto',
 'Allen Berube',
 'Anton Berzin',
 'Scott Bessac',
 'Fernando Bettega',
 'Jeremiah Billington',
 'Scott Bills',
 'Chris Birchler',
 'Amaury Bitetti',
 'Simon Biyong',
 'Jason Black',
 'Jason Blackford',
 'Tom Blackledge',
 'David Blanco',
 'Arlene Blencowe',
 'Byron Bloodworth',
 'Dashawn Boatwright',
 'Dan Bobish',
 'Jeremy Boczulak',
 'Jay Bogan',
 'Derek Bohi',
 'Jerry Bohlander',
 'Kotetsu Boku',
 'Kyle Bolt',
 'Luc Bondole',
 'Tony Bonello',
 'Jesse Bongfeldt',
 'Marcos Bonilla',
 'Igor Borisov',
 'Marcus Bossett',
 'Chris Bostick',
 'Francois Botha',
 'Gregory Bouchelaghem',
 'Roy Boughton',
 'Rich Bouphanouvong',
 'Mike Bourke',
 'Jess Bouscal',
 'Tai Bowden',
 'Melton Bowen',
 'Blake Bowman',
 'Ashe Bowman',
 'ColleyBradford',
 'Paul Bradley',
 'Ebenezer Fontes Braga',
 'Joe Brammer',
 'Michael Bravo',
 'Chris Brennan',
 'Robert Breslin',
 'Mack Brewer',
 'Aaron Brink',
 'Marcelo Brito',
 'Drew Brokenshire',
 'Mike Bronzoulis',
 'Lee Brousseau',
 'Dominic Brown',
 'Todd Brown',
 'Terrell Brown',
 'Chris Brown',
 'Frederick Brown',
 'Humberto Brown Morrison',
 'Junie Browning',
 'Jules Bruchez',
 'Justin Bruckmann',
 'Steve Bruno',
 'Fernando Bruno',
 'Josh Bryant',
 'Dennis Bryant',
 'Zak Bucia',
 'Courtney Buck',
 'Francisco Bueno',
 'Lee Kwan Bum',
 'Josh Bumgarner',
 'Shawn Bunch',
 'Mikey Burnett',
 'Josh Burns',
 'Derrick Burnsed',
 'Nah-Shon Burrell',
 'Martin Buschkamp',
 'George Bush',
 'Bubba Bush',
 'Murilo Bustamante',
 'Nick Bustamante',
 'Eduardo Bustillos',
 'Jason Butcher',
 'Todd Butler',
 'Goldman Butler',
 'Ian Butler',
 'Raphael Butler',
 'Steve Byrnes',
 'Michael Byrnes',
 'Alvin Cacdac',
 'Travis Calanoc',
 'Ricky Calatayud',
 'Darrion Caldwell',
 'Taylor Callens',
 'Joe Camacho',
 'Ricky Camp',
 'Mike Campbell',
 'Thomas Campbell',
 'John Campetella',
 'Wagner Campos',
 'Derek Campos',
 'Asbel Cancio',
 'Ronaldo Candido',
 'Jose Canseco',
 'Cody Canterbury',
 'Bo Cantrell',
 'Paul Capaldo',
 'Frank Caracci',
 'Gina Carano',
 'Dos Caras Jr.',
 'Remo Cardarelli',
 'Phil Cardella',
 'Edgar Cardenas',
 'Ronald Carillo',
 'Rafael Carino',
 'Don Carlo-Clauss',
 'Tim Caron',
 'Gabriel Carrasco',
 'Cody Carrillo',
 'Cain Carrizosa',
 'Roger Carroll',
 'Jonny Carson',
 'Scott Carson',
 'Shonie Carter',
 'Bruno Carvalho',
 'Rafael Carvalho',
 'Brandon Cash',
 'Bendy Casimir',
 'Dwayne Cason',
 'Joe Cason',
 'Eric Castile',
 'Gil Castillo',
 'Raul Castillo',
 'Jenna Castillo',
 'Tim Catalfo',
 'Luke Caudillo',
 'Adam Cella',
 'Jared Chaffee',
 'Ansar Chalangov',
 'Donnie Chappell',
 'Joe Charles',
 'Dan Charles',
 'Emilio Chavez',
 'Gabriel Checco',
 'Albert Cheng',
 'Ion Cherdivara',
 'Sako Chivitchian',
 'Mu Bae Choi',
 'Hong Man Choi',
 'Will Chope',
 'Dan Christison',
 'Anthony Christodoulou',
 'Murad Chunkaiev',
 'Steven Ciaccio',
 'Mike Ciesnolevicz',
 'Branko Cikatic',
 'Nikolajus Cilkinas',
 'Johnny Cisneros',
 'Laverne Clark',
 'Logan Clark',
 'Mychal Clark',
 'Dominic Clark',
 'John Clarke',
 'RJ Clifford',
 'Josh Clopton',
 'Brian Cobb',
 'Darryl Cobb',
 'Dave Cochran',
 'Dakota Cochrane',
 'Marc Cofer',
 'John Cofer',
 'Chris Coggins',
 'Wayne Cole',
 'Devin Cole',
 'Coltin Cole',
 'Ivan Cole',
 'Cortez Coleman',
 'Christian Colombo',
 'Wes Combs',
 'Chris Condo',
 'Marcos Conrado Jr.',
 'Jeremiah Constant',
 'Jonathan Contrestano',
 'Bob Cook',
 'Mike Cook',
 'Chad Cook',
 'TJ Cook',
 'Dewey Cooper',
 'Brett Cooper',
 'Bill Cooper',
 'Bobby Cooper',
 'Kit Cope',
 'Josh Copeland',
 'Muhsin Corbbrey',
 'Clint Coronel',
 'Henry Corrales',
 'Wesley Correira',
 'Chad Corvin',
 'Miguel Cosio',
 'Jadson Costa',
 'Guilherme Costa',
 'JC Cottrell',
 'JR Coughran',
 'Dave Courchaine',
 'Kim Couture',
 'Nikk Covert',
 'Jeff Cox',
 'Dan Cramer',
 'Alberto Crane',
 'Paul Creighton',
 'Alexander Crispim',
 'Alex Crispin',
 'Jeff Crotty',
 'Richard Crunkilton',
 'Marcio Cruz',
 'Jay Cucciniello',
 'Chris Culley',
 'Abel Cullum',
 'Everett Cummings',
 'Hugo Cunha',
 'Larry Cureton',
 'Pat Curran',
 'Gleidson Cutis',
 "Sarah D'alelio",
 'Marcos da Matta',
 'Henrique Da Silva Lopes',
 'Dave Dalgliesh',
 'Richard Dalton',
 'Marko Damiani',
 'Carina Damm',
 'Cindy Dandois',
 'Raymond Daniels',
 'Marques Daniels',
 'Alexandre Dantas',
 'Eduardo Dantas',
 'Sean Daugherty',
 'Brian Davidson',
 'Rick Davis',
 'Lemont Davis',
 'Mike Davis',
 'Justin Davis',
 'Danny Davis',
 'Angel De Anda',
 'Rodrigo de Lima',
 'Edilberto de Oliveira',
 'Johil de Oliveira',
 'Jorge de Oliveira',
 'Crezio de Souza',
 'Tom DeBlass',
 'Issac DeJesus',
 'RafaelDel Real',
 'Shane del Rosario',
 'Humberto DeLeon',
 'Israel Delgado',
 'Ante Delija',
 'Jack Della',
 'Jason DeLucia',
 'Justin DeMoney',
 'Nick Denis',
 'Thomas Denny',
 'Robert Densley',
 'Booker DeRousse',
 'Cory Devela',
 'John Devine',
 'Edwin DeWees',
 'Thomas Diagne',
 'Eldo Xavier Dias',
 'Rafael Dias',
 'Michael Diaz',
 'Ryan Diaz',
 'Adrian Diaz',
 'Mark Dickman',
 'Josh Diekmann',
 'Kyle Dietz',
 'Ralph Dillon',
 'Drew Dimanlig',
 'Rodolfo Marques Diniz',
 'Helio Dipp',
 'Rico DiSciullo',
 'John Dixson',
 'Anthony Do',
 'David Dodd',
 'Mike Dolce',
 'Cameron Dollar',
 'Dennis Dombrow',
 'OJ Dominguez',
 'John Donaldson',
 'Houston Dorr',
 'Geronimo dos Santos',
 'Antonio Dos Santos',
 'Oleksandr Doskalchuk',
 'David Douglas',
 'Damion Douglas',
 'John Dowdy',
 'Jordan Dowdy',
 'Derek Downey',
 'John Doyle',
 'Edson Drago',
 'Chris Drumm',
 'Robert Drysdale',
 'Hugo Duarte',
 'Antonio Duarte',
 'Joe Duarte',
 'Milana Dudieva',
 'Adin Duenas',
 'Alexis Dufresne',
 'Kelly Dullanty',
 'Alex Dunworth',
 'Luiz Dutra',
 'Rilley Dutro',
 'Bill Duvall',
 'Ben Earwood',
 'Cody East',
 'Maurice Eazel',
 'Vincent Eazelle',
 'Ross Ebanez',
 'Abdul-Kerim Edilov',
 'Adli Edwards',
 'Tom Egan',
 'Justin Eilers',
 'Jon Olav Einemo',
 'Per Eklund',
 'John Elam',
 'John Paul Elias',
 'Saul Elizondo',
 'Eddy Ellis',
 'Lisa Ellis',
 'Anna Elmose',
 'Aaron Ely',
 'Sovannahry Em',
 'Aleksander Emelianenko',
 'Marius Enache',
 'Kevin Engel',
 'Alex Enlund',
 'Kenny Ento',
 'Ian Entwistle',
 'Won Jin Eoh',
 'Josh Epps',
 'Tom Erikson',
 'Konstantin Erokhin',
 'Nick Ertl',
 'Chel Erwin-Davis',
 'Bobby Escalante',
 'Eric Esch',
 'Pro Escobedo',
 'Evan Esguerra',
 'Fred Ettish',
 'Scott Ettling',
 'Doug Evans',
 'Dan Evensen',
 'Neal Ewing',
 'Edward Faaloloto',
 'Ron Faircloth',
 'Jason Fairn',
 'Rinat Fakhretdinov',
 'Maiquel Falcao',
 'Brodie Farber',
 'Joao Paulo Faria',
 'Kalindra Faria',
 'Chance Farrar',
 'Kelly Faszholz',
 'Rodney Faverus',
 'JP Felty',
 'Rhadi Ferguson',
 'Josh Ferguson',
 'CJ Fernandes',
 'Bibiano Fernandes',
 'Alexandre Ferreira',
 'Scott Ferrozzo',
 'Scott Fiedler',
 'Ron Fields',
 'Anthony Figueroa',
 'Paulo Filho',
 'Brady Fink',
 'Jesse Finney',
 'Jan Finney',
 'Luiz Firmino',
 'Bryanna Fissori',
 'Isi Fitikefu',
 'Colin Fletcher',
 'Cody Floyd',
 'Bobby Flynn',
 'Mal Foki',
 'Matt Foki',
 'AJ Fonseca',
 'Claudionor Fontinelle',
 'Sterling Ford',
 'Codale Ford',
 'Xavier Foupa-Pokam',
 'Mason Fowler',
 'Brandon Foxworth',
 'Francisco France',
 'Zoila Frausto',
 'Zane Frazier',
 'Gary Frazier',
 'Ian Freeman',
 'Jason Freeman',
 'Willamy Freire',
 'JeremyFreitag',
 'Rafael Freitas',
 'Donavon Frelow',
 'Clay French',
 'Mike French',
 'Artem Frolov',
 'Don Frye',
 'Tony Fryklund',
 'Jesse Fujarczyk',
 'Katsuhisa Fujii',
 'Megumi Fujii',
 'Kazuyuki Fujita',
 'Keisuke Fujiwara',
 'Travis Fulton',
 'Sam Fulton',
 'Masakatsu Funaki',
 'Katsuaki Furuki',
 'James Gabert',
 'Gustavo Gabriel',
 'Alavutdin Gadjiev',
 'Sheila Gaff',
 'Brandon Gaines',
 'Travis Galbraith',
 'Dave Galera',
 'Zelg Galesic',
 'Daniel Gallemore',
 'Tom Gallicchio',
 'Turrell Galloway',
 'Eric Galvan',
 'Andre Galvao',
 'Marcos Galvao',
 'Lucas Gamaza',
 'Joey Gambino',
 'Ariel Gandulla',
 'Sean Gannon',
 'Alejandro Garcia',
 'Nick Garcia',
 'Rulon Gardner',
 'David Gardner',
 'Azamat Gashimov',
 'Brian Gassaway',
 'Manuel Gaxhja',
 'Charlene Gellner',
 'Paul Georgieff',
 'Brian Geraghty',
 'Derek Getzel',
 'Darrel Gholar',
 'Tiki Ghosn',
 'Nick Gibbons',
 'James Giboo',
 'Lance Gibson',
 'Lee Gibson',
 'Kenny Giddens',
 'Joseph Gigliotti',
 'Joey Gilbert',
 'Kultar Gill',
 'Jesse Gillespie',
 'Jason Gilliam',
 'Krishaun Gilmore',
 'Alex Gilpin',
 'Bob Gilstrap',
 'Demetrius Gioulacos',
 'Billy Giovanella',
 'He-Man Gipson',
 'Israel Giron',
 'Brandon Girtz',
 'Jason Glaza',
 'Mike Glenn',
 'Clint Godfrey',
 'Jason Godsey',
 'Allan Goes',
 'Jonny Goh',
 'Sergio Gomez',
 'Alan Gomez',
 'David Gomez',
 'Ulysses Gomez',
 'Nick Gonzalez',
 'Fabian Gonzalez',
 'Lewis Gonzalez',
 'Pearl Gonzalez',
 'Jennifer Gonzalez',
 'Kier Gooch',
 'Gary Goodridge',
 'Jordan Goodwin',
 'Gerard Gordeau',
 'Tebaris Gordon',
 'Tim Gorman',
 'Chase Gormley',
 'Todd Gouwenberg',
 'Hugo Govea',
 'Justin Governale',
 'Royce Gracie',
 'Crosley Gracie',
 'Daniel Gracie',
 'Ralph Gracie',
 'Renzo Gracie',
 'Rickson Gracie',
 'Rodrigo Gracie',
 'Royler Gracie',
 'Ryan Gracie',
 'Ralek Gracie',
 'Rolles Gracie',
 'Cesar Gracie',
 'Igor Gracie',
 'Neiman Gracie',
 'Steven Graham',
 'Scott Graham',
 'James Gray',
 'Sam Greco',
 'Chuck Grigsby',
 'Rodrigo Gripp de Sousa',
 'Garrett Gross',
 'Neil Grove',
 'Nandor Guelmino',
 'Fabricio Guerreiro',
 'Jason Guida',
 'Chris Guillen',
 'Leonardo Guimaraes',
 'Brad Gumm',
 'Fabio Gurgel',
 'Andre Gusmao',
 'Justin Guthrie',
 'Horacio Gutierrez',
 'Keith Hackney',
 'Steve Hadsel',
 'Yazan Hajeh',
 'Stoney Hale',
 'Kevin Haley',
 'Mark Hall',
 'Tony Halme',
 'Brandon Halsey',
 'John Halverson',
 'Frank Hamaker',
 'Kazuhiro Hamanaka',
 'Jeremy Hamilton',
 'James Hammortree',
 'Dean Hancock',
 'Joachim Hansen',
 'Janay Harding',
 'Baru Harn',
 'Scott Harper',
 'Gerry Harris',
 'Dhafir Harris',
 'Trevor Harris',
 'Collin Hart',
 'Luke Hartwig',
 'Hidehiko Hasegawa',
 'Chris Haseman',
 'Takayo Hashi',
 'Tomohiko Hashimoto',
 'Justin Haskins',
 'Hayder Hassan',
 'Daiki Hata',
 'Justin Hawes',
 'Chris Hawk',
 'Del Hawkins',
 'Tommy Hayden',
 'Mike Hayes',
 'Ryan Hayes',
 'Gerric Hayes',
 'Josh Haynes',
 'Ryan Healy',
 'Spencer Hearns',
 'Chris Heatherly',
 'Delson Heleno',
 'Matt Helm',
 'Elisha Helsper',
 'Ron Henderson',
 'Josh Hendricks',
 'Cory Hendricks',
 'Diego Henrique da Silva',
 'TJ Hepburn',
 'Noe Hernandez',
 'Joe Hernandez',
 'Ramiro Hernandez',
 'Paul Herrera',
 'Chris Herrera',
 'Jon Hess',
 'Brandon Hester',
 'Conor Heun',
 'Lee Higgins',
 'Richie Hightower',
 'Alex Higley',
 'Isaiah Hill',
 'Tyler Hill',
 'Branden Lee Hinkle',
 'Alan Hiro',
 'Yuji Hisamatsu',
 'Kwan Ho Kwak',
 'Bobby Hoffman',
 'Sam Hoger',
 'Sean Holden',
 'Chris Holdsworth',
 'Roger Hollett',
 'Gabrielle Holloway',
 'Jeremie Holloway',
 'Rex Holman',
 'Ben Holscher',
 'Mark Holst',
 'Satoshi Honma',
 'David Hood',
 'Moti Horenstein',
 'Matt Horning',
 'Jamey-Lyn Horth',
 'Matt Horwich',
 'John Hosman',
 'Saeed Hosseini',
 'Trey Houston',
 'Jamie Houston',
 'Brian Houston',
 'Harold Howard',
 'Shane Howell',
 'Alex Huddleston',
 'Casey Huffman',
 'Mark Hughes',
 'David Hulett',
 'Bryan Humes',
 'Abongo Humphrey',
 'Alex Hunter',
 'Adam Hunter',
 'Joe Hurley',
 'Solomon Hutcherson',
 'Minoki Ichihara',
 'Valeri Ignatov',
 'Sergey Ignatov',
 'Fabiano Iha',
 'Seichi Ikemoto',
 'Mikhail Iloukhine',
 'Yusuke Imamura',
 'Masakazu Imanari',
 'Brad Imes',
 'Chris Indich',
 'Chris Inman',
 'Guto Inocente',
 'Enson Inoue',
 'Egan Inoue',
 'Katsuya Inoue',
 'Takeshi Inoue',
 'Jorge Interiano',
 'Jason Ireland',
 'Eric Irvin',
 'Mitsuhiro Ishida',
 'Satoshi Ishii',
 'Yuki Ishikawa',
 'Eiji Ishikawa',
 'Tokimitsu Ishizawa',
 'Wallid Ismail',
 'Tomomi Iwama',
 'Tatsuya Iwasaki',
 'Yoislandy Izquierdo',
 'Hiroshi Izumi',
 'Kevin Jackson',
 'Eugene Jackson',
 'Jeremy Jackson',
 'Kenyon Jackson',
 'Mike Jackson',
 'Eric Jacob',
 'Justin James',
 'Nate James',
 'Josh Janousek',
 'Jaime Jara',
 'Gigo Jara',
 'Brock Jardine',
 'Josh Jarvis',
 'Louis Jauregui',
 'Trent Jenkins',
 'Bubba Jenkins',
 'Adrienna Jenkins',
 'Steve Jennum',
 'Kyle Jensen',
 'Chan-Mi Jeon',
 'Maciej Jewtuszko',
 'Ronald Jhun',
 'Gilbert Jimenez',
 'Art Jimmerson',
 'Phil Johns',
 'Devin Johnson',
 'Travis Johnson',
 'Ricky Johnson',
 'Deshaun Johnson',
 'Dashon Johnson',
 'Tony Johnson',
 'Brian Johnston',
 'Paul Jones',
 'Nathan Jones',
 'Marcus Jones',
 'Carlton Jones',
 'Jesse Jones',
 'Tito Jones',
 'Roy Jones',
 'Justin Jones',
 'Ben Jones',
 'Victor Jones',
 'Chris Jones',
 'Roshaun Jones',
 'Antonio Jones',
 'Kevin Jordan',
 'Joe Jordan',
 'Gareth Joseph',
 'Dwight Joseph',
 'Jeff Joslin',
 'Mike Joy',
 'Tony Juarez',
 'Jesse Juarez',
 'Steve Judson',
 'Bu-Kyung Jung',
 'Young Sam Jung',
 'Scott Junk',
 'Patrick Kaase',
 'Emily Kagan',
 'Sirwan Kakai',
 'Geza Kalman',
 'Bryson Kamaka',
 'Hiromitsu Kanehara',
 'Ken Kaneko',
 'David Kaplan',
 'Georgi Karakhanyan',
 'Yusuke Kasuya',
 'Tetsuji Kato',
 'Hisaki Kato',
 'Yusuke Kawaguchi',
 'Ryo Kawamura',
 'Doug Kay',
 'Julie Kedzie',
 'Ryan Keenan',
 'CJ Keith',
 'Mayana Kellem',
 'John Kelly',
 'Steve Kennedy',
 'Waylon Kennell',
 'Aurelijus Kerpe',
 'Mark Kerr',
 'Ron Keslar',
 'Adam Khaliev',
 'Sergei Kharitonov',
 'Akira Kikuchi',
 'Sanae Kikuta',
 'Jin Oh Kim',
 'Dae Won Kim',
 'Jong Wang Kim',
 'Jong Won Kim',
 'Min Soo Kim',
 'Jong Man Kim',
 'Taiei Kin',
 'Mike King',
 'Yurij Kiseliov',
 'Koji Kitao',
 'Satoru Kitaoka',
 'Seth Kleinbeck',
 'Stefan Klever',
 'Michael Knaap',
 'Kevin Knabjian',
 'Isao Kobayashi',
 'Kelly Kobold',
 'Sokun Koh',
 'Shingo Kohara',
 'Brad Kohler',
 'Charlie Kohler',
 'Tsuyoshi Kohsaka',
 'John Kolosci',
 'Yuki Kondo',
 'Andrei Kopylov',
 'Andrey Koreshkov',
 'Ilya Kotau',
 'Iouri Kotchkine',
 'Matt Kovacs',
 'Marcus Kowal',
 'Steve Kozola',
 'Pascal Krauss',
 'Rene Kronvold',
 'Jorgen Kruth',
 'Junya Kudo',
 'John Kuhner',
 'Maiju Kujala',
 'Keigo Kunihara',
 'Leo Kuntz',
 'Tsuyoshi Kurihara',
 'Eldari Kurtanidze',
 'Kyle Kurtz',
 'Lina Kvokov',
 'Kaleo Kwan',
 'Jarrod Kwitty',
 'Achmed Labasanov',
 'Josh LaBerge',
 'Jeremiah Labiano',
 'Kemran Lachinov',
 'Ben Lagman',
 'Tina Lahdemaki',
 'Tim Lajcik',
 'Todd Lally',
 'Sean Lally',
 'Jose Landi-Jons',
 'Austen Lane',
 'Aaron Lanfranco',
 'Jeremy Lang',
 'Lionel Lanham',
 'Anthony Lapsley',
 'Icho Larenas',
 'Ryan Larson',
 'Sione Latu',
 'Dan Lauzon',
 'Chatt Lavender',
 'Eric Lawson',
 'Jerome LeBanner',
 'Stephen Ledbetter',
 'James Lee',
 'David Lee',
 'Jackie Lee',
 'Eun Soo Lee',
 'Tae Hyun Lee',
 'Tommy Lee',
 'Matt Lee',
 'Imani Lee',
 'Rocky Lee',
 'Ricky Legere Jr.',
 'Sherron Leggett',
 'Stefan Leko',
 'Gabe Lemley',
 'Christophe Leninger',
 'Jean Francois Lenogue',
 'Alberta Cerra Leon',
 'Anthony Leone',
 'Chad Leonhardt',
 'Kimo Leopoldo',
 'Michael Lerma',
 'Lukasz Les',
 'Frank Lester',
 'Justin Levens',
 'David Levicki',
 'Kyle Levinton',
 'John Lewis',
 'Chi Lewis-Parry',
 'Jess Liaudin',
 'Sam Liera',
 'Zach Light',
 'Scott Lighty',
 'Chris Liguori',
 'Donnie Liles',
 'Jae Suk Lim',
 'Douglas Lima',
 'Mabelly Lima',
 'Miguel Linares',
 'Jake Lindsey',
 'Lucio Linhares',
 'Wesley Little',
 'Abner Lloveras',
 'Brian Lo-A-Njoe',
 'John Lober',
 'Sean Loeffler',
 'Rocky Long',
 'Thomas Longacre',
 'Lucas Lopes',
 'Dileno Lopes',
 'Ivan Lopez',
 'Steve Lopez',
 'Federico Lopez',
 'Jorge Lopez',
 'Christopher Lopez',
 'Nate Loughran',
 'Rashard Lovelace',
 'Ian Loveland',
 'Jakob Lovstad',
 'Waylon Lowe',
 'Brandon Lowe',
 'Robert Lucarelli',
 'Matt Lucas',
 'Cleber Luciano',
 'Mike Lullo',
 'Alexandru Lungu',
 'Thaddeus Luster',
 'Stevie Lynch',
 ]

# Initialize a results dictionary
full_results = {'Name': [], 'Found In': [], 'Action': []}

# Iterate through all files and search for names
for file_name, file_path in files_to_search.items():
    df = pd.read_csv(file_path)  # Load each file into a DataFrame
    for name in full_names_with_nan:
        if name in df.values:  # Check if the name exists in the dataset
            if name not in full_results['Name']:  # Avoid duplicates
                full_results['Name'].append(name)
                full_results['Found In'].append(file_name)
                full_results['Action'].append('Research')

# Identify names not found in any dataset
not_found_full = [name for name in full_names_with_nan if name not in full_results['Name']]
full_results['Name'].extend(not_found_full)
full_results['Found In'].extend(['None'] * len(not_found_full))
full_results['Action'].extend(['Delete'] * len(not_found_full))

# Convert results to a DataFrame
full_results_df = pd.DataFrame(full_results)

# Save the results to a CSV file for easy viewing
output_file = "full_search_results.csv"
full_results_df.to_csv(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# Results saved to full_search_results.csv

# %%
# Load the uploaded file
file_path = "full_search_results.csv"
results_df = pd.read_csv(file_path)

# Filter out rows where 'Action' is 'Delete' or 'Found In' is 'None'
filtered_df = results_df[(results_df['Action'] != 'Delete') & (results_df['Found In'] != 'None')]

# Save the filtered DataFrame to a new CSV file
filtered_file_path = "data/filtered_search_results.csv"
filtered_df.to_csv(filtered_file_path, index=False)

filtered_df.head()
#import ace_tools as tools; tools.display_dataframe_to_user(name="Filtered Search Results", dataframe=filtered_df)
# Out:
#             Name               Found In    Action
# 0   Danny Abbadi  Cleaner_Fight_Results  Research
# 1   David Abbott  Cleaner_Fight_Results  Research
# 2     Papy Abedi  Cleaner_Fight_Results  Research
# 3  Ricardo Abreu  Cleaner_Fight_Results  Research
# 4    Scott Adams  Cleaner_Fight_Results  Research

# %%
event.to_csv('fight_event.csv', index=False)

# %%
fight_details.to_csv('fight_details.csv', index=False)

# %%
fight_stats.to_csv('fight_stats.csv', index=False)

# %%
fighter_details.to_csv('fighter_details.csv', index=False)

# %%
fighter_tott.to_csv('fighter_tott.csv', index=False)

# %%
fight_results.to_csv('fight_results.csv', index=False)
